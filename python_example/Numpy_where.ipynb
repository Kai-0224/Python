# %%
import numpy as np

# %%
a = [1,2,3,4,5,6,7]
a = np.array(a)

# %%
c = np.where(a == 5)

# %%
if not c:
    print(-1)
else:
    print(c)
# Out:
# (array([4]),)

# %%
b = [1]
b = np.array(b)

# %%
position = np.where(b == 1)

# %%
position
# Out:
# array([0])

# %%
len(position)
# Out:
# 1

# %%
if not position:
    print(-1)
else:
    print(position[0])
# Out:
# -1

# %%
b[0],b[-1]
# Out:
# (1, 1)
