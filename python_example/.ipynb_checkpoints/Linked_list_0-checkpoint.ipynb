# %%
class ListNode:
    def __init__(self, data): 
        # store data
        self.data = data
        # store the reference (next item)
        self.next = None
        return

# %%
node1 = ListNode(15)

# %%
class SingleLinkedList:
    def __init__(self): 
        self.head = None
        self.tail = None
        return

# %%
def add_list_item(self, item):
    # make sure item is a proper node  
    if not isinstance(item, ListNode):
        item = ListNode(item)
    
    if self.head is None:
        self.head = item
    else:
        self.tail.next = item
    
    self.tail = item
    return

# %%
list1 = SingleLinkedList()
list1.add_list_item(node1)
list1.add_list_item(12)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 2
#       1 list1 = SingleLinkedList()
# ----> 2 list1.add_list_item(node1)
#       3 list1.add_list_item(12)
#
# AttributeError: 'SingleLinkedList' object has no attribute 'add_list_item'
