# %%
values = {'M':1000,
         'CM':900,
         'D':500,
         'CD':400,
         'C':100,
         'XC':90,
         'L':50,
         'XL':40,
         'X':10,
         'IX':9,
         'V':5,
         'IV':4,
         'I':1} #Dict with order from larger to smaller

# %%
for value in values:
    print(value)
# Out:
# M
# CM
# D
# CD
# C
# XC
# L
# XL
# X
# IX
# V
# IV
# I

# %%
values.items()
# Out:
# dict_items([('M', 1000), ('CM', 900), ('D', 500), ('CD', 400), ('C', 100), ('XC', 90), ('L', 50), ('XL', 40), ('X', 10), ('IX', 9), ('V', 5), ('IV', 4), ('I', 1)])

# %%
values.keys()
# Out:
# dict_keys(['M', 'CM', 'D', 'CD', 'C', 'XC', 'L', 'XL', 'X', 'IX', 'V', 'IV', 'I'])

# %%
values.values()
# Out:
# dict_values([1000, 900, 500, 400, 100, 90, 50, 40, 10, 9, 5, 4, 1])

# %%
dict2 = values.copy()

# %%
dict2.get("X")
# Out:
# 10
