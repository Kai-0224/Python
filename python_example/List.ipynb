# %%
ls1 = [1, 3, 5, 3, 45]
ls2 = [2, 3, 5]

# %%
ls3 = ls1 + ls2

# %%
ls3
# Out:
# [1, 3, 5, 3, 45, 2, 3, 5]

# %%
ls1.extend(ls2)

# %%
ls1
# Out:
# [1, 3, 5, 3, 45, 2, 3, 5]

# %%
a = ls3*3

# %%
a
# Out:
# [1, 3, 5, 3, 45, 2, 3, 5, 1, 3, 5, 3, 45, 2, 3, 5, 1, 3, 5, 3, 45, 2, 3, 5]

# %%
import numpy as np
b = np.array(ls3)*3

# %%
b
# Out:
# array([  3,   9,  15,   9, 135,   6,   9,  15])

# %%
not []
# Out:
# True

# %%
not [3]
# Out:
# False

# %%
not ""
# Out:
# True

# %%
not 0
# Out:
# True

# %%
not 1
# Out:
# False
